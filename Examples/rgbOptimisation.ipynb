# %%
import matplotlib.pyplot as plt
import pymiediff as pmd
import torch
import numpy as np

# %%
starting_wavelength = 380  # nm
ending_wavelength = 750  # nm

N_pt_test = 250

wl = torch.linspace(
    starting_wavelength,
    ending_wavelength,
    N_pt_test,
    dtype=torch.double,
    requires_grad=False,
)

k0 = 2 * torch.pi / wl

# %%
core_radius = 1.0  # nm
shell_radius = 40.0  # nm
core_refractiveIndex = 1.45 + 0.0j
shell_refractiveIndex = 7 + 0.01j

# %%
optim_expression="q_sca"

# %%
q_sca_start = pmd.farfield.cross_sections(
    k0=k0,
    r_c=core_radius,
    eps_c=core_refractiveIndex ** 2,
    r_s=shell_radius,
    eps_s=shell_refractiveIndex ** 2,
    eps_env=1.44,
    n_max=8,
)[optim_expression]

plt.plot(wl.detach(), q_sca_start.detach(), label = "Starting spetra.")
plt.xlabel("$\lambda$ (nm)")
plt.ylabel(optim_expression)
plt.show()

# %%
r_c = torch.tensor(core_radius, requires_grad=True)
r_s = torch.tensor(shell_radius, requires_grad=True)
n_c = torch.tensor(core_refractiveIndex, requires_grad=False)
n_s = torch.tensor(shell_refractiveIndex, requires_grad=True)

# %%
def FOM(args, wl_target_indx):

    sca_iter = pmd.farfield.cross_sections(*args)["q_sca"]
    abs_iter = pmd.farfield.cross_sections(*args)["q_abs"]

    sca_mean = torch.mean(sca_iter)

    abs_max = torch.max(abs_iter)

    return torch.mean(sca_iter[wl_target_indx])/(2*sca_mean + abs_max)

# %%
wl
# Out:
# tensor([380.0000, 381.4859, 382.9719, 384.4578, 385.9438, 387.4297, 388.9157,
#         390.4016, 391.8876, 393.3735, 394.8594, 396.3454, 397.8313, 399.3173,
#         400.8032, 402.2892, 403.7751, 405.2610, 406.7470, 408.2329, 409.7189,
#         411.2048, 412.6908, 414.1767, 415.6627, 417.1486, 418.6345, 420.1205,
#         421.6064, 423.0924, 424.5783, 426.0643, 427.5502, 429.0361, 430.5221,
#         432.0080, 433.4940, 434.9799, 436.4659, 437.9518, 439.4378, 440.9237,
#         442.4096, 443.8956, 445.3815, 446.8675, 448.3534, 449.8394, 451.3253,
#         452.8112, 454.2972, 455.7831, 457.2691, 458.7550, 460.2410, 461.7269,
#         463.2129, 464.6988, 466.1847, 467.6707, 469.1566, 470.6426, 472.1285,
#         473.6145, 475.1004, 476.5863, 478.0723, 479.5582, 481.0442, 482.5301,
#         484.0161, 485.5020, 486.9880, 488.4739, 489.9598, 491.4458, 492.9317,
#         494.4177, 495.9036, 497.3896, 498.8755, 500.3614, 501.8474, 503.3333,
#         504.8193, 506.3052, 507.7912, 509.2771, 510.7631, 512.2490, 513.7349,
#         515.2209, 516.7068, 518.1928, 519.6787, 521.1647, 522.6506, 524.1365,
#         525.6225, 527.1084, 528.5944, 530.0803, 531.5663, 533.0522, 534.5382,
#         536.0241, 537.5100, 538.9960, 540.4819, 541.9679, 543.4538, 544.9398,
#         546.4257, 547.9116, 549.3976, 550.8835, 552.3695, 553.8554, 555.3414,
#         556.8273, 558.3133, 559.7992, 561.2851, 562.7711, 564.2570, 565.7430,
#         567.2289, 568.7149, 570.2008, 571.6867, 573.1727, 574.6586, 576.1446,
#         577.6305, 579.1165, 580.6024, 582.0884, 583.5743, 585.0602, 586.5462,
#         588.0321, 589.5181, 591.0040, 592.4900, 593.9759, 595.4618, 596.9478,
#         598.4337, 599.9197, 601.4056, 602.8916, 604.3775, 605.8635, 607.3494,
#         608.8353, 610.3213, 611.8072, 613.2932, 614.7791, 616.2651, 617.7510,
#         619.2369, 620.7229, 622.2088, 623.6948, 625.1807, 626.6667, 628.1526,
#         629.6386, 631.1245, 632.6104, 634.0964, 635.5823, 637.0683, 638.5542,
#         640.0402, 641.5261, 643.0120, 644.4980, 645.9839, 647.4699, 648.9558,
#         650.4418, 651.9277, 653.4137, 654.8996, 656.3855, 657.8715, 659.3574,
#         660.8434, 662.3293, 663.8153, 665.3012, 666.7871, 668.2731, 669.7590,
#         671.2450, 672.7309, 674.2169, 675.7028, 677.1888, 678.6747, 680.1606,
#         681.6466, 683.1325, 684.6185, 686.1044, 687.5904, 689.0763, 690.5622,
#         692.0482, 693.5341, 695.0201, 696.5060, 697.9920, 699.4779, 700.9639,
#         702.4498, 703.9357, 705.4217, 706.9076, 708.3936, 709.8795, 711.3655,
#         712.8514, 714.3373, 715.8233, 717.3092, 718.7952, 720.2811, 721.7671,
#         723.2530, 724.7390, 726.2249, 727.7108, 729.1968, 730.6827, 732.1687,
#         733.6546, 735.1406, 736.6265, 738.1124, 739.5984, 741.0843, 742.5703,
#         744.0562, 745.5422, 747.0281, 748.5141, 750.0000], dtype=torch.float64)

# %%
lower_bound = 457.5 #458.0
upper_bound = 459.5

wl_target_indx = torch.nonzero((wl >= lower_bound) & (wl <= upper_bound), as_tuple=True)

# %%
wl_target_indx
# Out:
# (tensor([53]),)

# %%
q_sca_start[wl_target_indx]
# Out:
# tensor([2.5765], dtype=torch.float64)

# %%
import torch
import time

t0 = time.time()
optimizer = torch.optim.LBFGS([r_c, r_s, n_s], lr=0.01, max_iter=10, history_size=5) # LBFGS-specific params

max_iter = 50
losses = []  # Array to store loss data

def closure():
    optimizer.zero_grad()  # Reset gradients

    args = (k0, r_c, n_c**2, r_s, n_s**2, 1.44)

    penalty_loss =  0.01 / n_s.real + 0.01 / n_s.imag

    # iteration_n = pmd.farfield.cross_sections(*args)[optim_expression]
    loss = 1/FOM(args, wl_target_indx) + penalty_loss

    loss.backward()  # Compute gradients
    return loss

for o in range(max_iter + 1):
    loss = optimizer.step(closure)  # LBFGS requires closure

    losses.append(loss.item())  # Store loss value

    if o % 5 == 0:
        print(o, loss.item())

t1 = time.time()
print(t1 - t0)
# Out:
# 0 2.655483783608254
# 5 2.2876278785928177
# 10 2.256566534573782
# 15 2.2231025567857143
# 20 2.1865249091617667
# 25 2.146673492981394
# 30 2.1034899249944123
# 35 1.7591829577758646
# 40 1.6836751488547916
# 45 1.6788648654769363
# 50 1.6739334662616059
# 413.105349779129

# %%
print("final:", [f"{d.detach().numpy():.3f}" for d in [r_c, r_s, n_c, n_s]])


args = (k0, r_c, n_c**2, r_s, n_s**2)

q_sca = pmd.farfield.cross_sections(*args)["q_sca"]
q_abs = pmd.farfield.cross_sections(*args)["q_abs"]
# Out:
# final: ['1.000', '39.988', '1.450+0.000j', '6.904+0.023j']

# %%
plt.plot(wl.detach(), q_sca.detach(), label = "Optimised sca.")
plt.plot(wl.detach(), q_abs.detach(), label = "Optimised abs.")
#plt.ylim([-2, 2])
plt.xlabel("$\lambda$ (nm)")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(5, 4))
plt.subplot(title="Loss curve.")
plt.plot(losses)
plt.xlabel("Iteration Num.")
plt.ylabel("Loss")
plt.yscale("log")
plt.show()
